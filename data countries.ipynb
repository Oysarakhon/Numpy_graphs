# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [3, 5, 7]
z = [3, 7, 9]
plt.plot(x,z)
plt.plot(x,y)
plt.title("countries figures")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
sample_data = pd.read_csv('countries.csv')

# %%
sample_data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.plot(sample_data.country, sample_data.population)
plt.plot(sample_data.country, sample_data.year)
plt.show()

# %%
us = sample_data[sample_data.country == 'United States']

# %%
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
china = sample_data[sample_data.country == 'China']

# %%
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year, us.population/ 10**6)
plt.plot(china.year, china.population/ 10**6)
plt.legend(["United States", "China"])
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %%
afghanistan = sample_data[sample_data.country == 'Afghanistan']

# %%
afghanistan
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
zim = sample_data[sample_data.country == 'Zimbabwe']

# %%
zim
# Out:
#        country  year  population
# 1692  Zimbabwe  1952     3080907
# 1693  Zimbabwe  1957     3646340
# 1694  Zimbabwe  1962     4277736
# 1695  Zimbabwe  1967     4995432
# 1696  Zimbabwe  1972     5861135
# 1697  Zimbabwe  1977     6642107
# 1698  Zimbabwe  1982     7636524
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
plt.plot(afghanistan.year, afghanistan.population/ 10**6)
plt.plot(zim.year, zim.population/ 10**6)
plt.legend(["Afghanistan", "Zimbabwe"])
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('countries.csv')

us = data[data.country == 'Afghanistan']

china = data[data.country =='Zimbabwe']

plt.plot(afghanistan.year, afghanistan.population/afghanistan.population.iloc[0]*100,)
plt.plot(zim.year, zim.population/zim.population.iloc[0]*100)
plt.legend(['Aghanistan', 'Zimbabwe'])
plt.xlabel('year')
plt.ylabel('population growth indexed at year 0')
plt.show()

# %%
sin = sample_data[sample_data.country == 'Singapore']

# %%
sin
# Out:
#         country  year  population
# 1356  Singapore  1952     1127000
# 1357  Singapore  1957     1445929
# 1358  Singapore  1962     1750200
# 1359  Singapore  1967     1977600
# 1360  Singapore  1972     2152400
# 1361  Singapore  1977     2325300
# 1362  Singapore  1982     2651869
# 1363  Singapore  1987     2794552
# 1364  Singapore  1992     3235865
# 1365  Singapore  1997     3802309
# 1366  Singapore  2002     4197776
# 1367  Singapore  2007     4553009

# %%
ser = sample_data[sample_data.country == 'Serbia']

# %%
ser
# Out:
#      country  year  population
# 1332  Serbia  1952     6860147
# 1333  Serbia  1957     7271135
# 1334  Serbia  1962     7616060
# 1335  Serbia  1967     7971222
# 1336  Serbia  1972     8313288
# 1337  Serbia  1977     8686367
# 1338  Serbia  1982     9032824
# 1339  Serbia  1987     9230783
# 1340  Serbia  1992     9826397
# 1341  Serbia  1997    10336594
# 1342  Serbia  2002    10111559
# 1343  Serbia  2007    10150265

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('countries.csv')

sin = data[data.country == 'Singapore']

ser = data[data.country =='Serbia']

plt.plot(sin.year, sin.population/sin.population.iloc[0]*100,)
plt.plot(ser.year, ser.population/ser.population.iloc[0]*100)
plt.legend(['Singapore', 'Serbia'])
plt.xlabel('year')
plt.ylabel('population growth indexed at year 0')
plt.show()
